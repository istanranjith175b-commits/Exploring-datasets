# %% [markdown]
# <a href="https://colab.research.google.com/github/istanranjith175b-commits/Exploring-datasets/blob/main/exp5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
data={'height':[123,178,156,186,154,134,176,198,153],
      'age':[12,45,56,32,43,22,65,12,18]}
df=pd.DataFrame(data)
print("Original data:\n",df,"\n")
# Out:
# Original data:
#     height  age
# 0     123   12
# 1     178   45
# 2     156   56
# 3     186   32
# 4     154   43
# 5     134   22
# 6     176   65
# 7     198   12
# 8     153   18

# %%
min_max_scaler = MinMaxScaler()
df_min_max = pd.DataFrame(
min_max_scaler.fit_transform(df),
columns=df.columns
)
print("Min-Max Scaled Data:\n", df_min_max, "\n")
# Out:
# Min-Max Scaled Data:
#       height       age
# 0  0.000000  0.000000
# 1  0.733333  0.622642
# 2  0.440000  0.830189
# 3  0.840000  0.377358
# 4  0.413333  0.584906
# 5  0.146667  0.188679
# 6  0.706667  1.000000
# 7  1.000000  0.000000
# 8  0.400000  0.113208

# %%
standard_scaler = StandardScaler()
df_standard = pd.DataFrame(
standard_scaler.fit_transform(df),
columns=df.columns
)
print("Standardized Data:\n", df_standard, "\n")
# Out:
# Standardized Data:
#       height       age
# 0 -1.686993 -1.195147
# 1  0.692100  0.606674
# 2 -0.259537  1.207281
# 3  1.038150 -0.103135
# 4 -0.346050  0.497472
# 5 -1.211175 -0.649141
# 6  0.605587  1.698686
# 7  1.557224 -1.195147
# 8 -0.389306 -0.867543
